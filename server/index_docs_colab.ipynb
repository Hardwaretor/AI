# %% [markdown]
# # Colab: preparar y ejecutar el servidor del proyecto
# Notebook mínimo para clonar el repositorio, instalar dependencias, (opcional) montar Drive, exponer con ngrok y ejecutar el servidor.
#
# Edita las celdas según necesites (por ejemplo, `REPO_URL` y `ngrok` token).

# %%
# Actualizar paquetes del sistema e instalar herramientas básicas
# !apt-get update -y && apt-get install -y build-essential git || true
# !pip install --upgrade pip

# %%
import os
os.environ.setdefault('ENV','dev')
print('ENV=', os.environ['ENV'])

# %%
# Montar Google Drive si lo necesitas (descomentar)
# from google.colab import drive
# drive.mount('/content/drive')
print('Drive mount: commented by default')

# %%
# Clonar repo (cambia REPO_URL por tu repositorio).
REPO_URL = 'https://github.com/tu_usuario/tu_repo.git'
# !git clone $REPO_URL repo || true
# %cd repo || true

# %%
# Instalar dependencias de Python (ajusta la ruta si es necesario)
# !pip install -r requirements.txt || true

# %%
# (Opcional) exponer puerto con ngrok
# !pip install pyngrok || true
from pyngrok import ngrok
# token = 'PON_AQUI_TU_TOKEN'
# ngrok.set_auth_token(token)
# public_url = ngrok.connect(8080)
# print('ngrok public url:', public_url)
print('ngrok: instrucciones opcionales (token comentado)')

# %%
# Iniciar servidor de ejemplo (ajusta el comando según tu proyecto)
# Ejemplo para FastAPI: uvicorn server.main:app --host 0.0.0.0 --port 8080 &
# !pip install uvicorn || true
# !uvicorn server.main:app --host 0.0.0.0 --port 8080 &
print('uvicorn lanzado en background (si el proyecto tiene esa entrada)')

# %%
# Ver procesos y logs básicos
# !ps aux | grep uvicorn || true

# %%
# Ejecutar pruebas si existen
# !pytest -q || true

# %% [markdown]
# ## Notas de uso
# - Reemplaza `REPO_URL` por la URL real de tu repositorio.
# - Para exponer el servidor públicamente usa ngrok (descomenta y añade token).
# - Ajusta el comando de arranque del servidor según la estructura de tu proyecto.
#
# Puedes abrir este notebook en Colab subiendo el archivo o usando la URL de GitHub si lo subes al repositorio.
